# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#TASK-1: DOWNLOADED THE DATASET ALREADY

# %%
#TASK-2: LOAD THE DATASET
df=pd.read_csv('C:\\Users\\putikam yashwanth\\Downloads\\SI_Assign-3\\penguins_size.csv')

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
#TASK-3:  Perform Below Visualizations.
#● Univariate Analysis
sns.distplot(df.culmen_length_mm)
# Out:
# C:\Users\putikam yashwanth\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='culmen_length_mm', ylabel='Density'>

# %%
#bivariate analysis
sns.lineplot(x=df.culmen_depth_mm,y=df.sex)
# Out:
# <AxesSubplot:xlabel='culmen_depth_mm', ylabel='sex'>

# %%
#bivariate analysis
sns.scatterplot(x=df.culmen_depth_mm,y=df.sex)
# Out:
# <AxesSubplot:xlabel='culmen_depth_mm', ylabel='sex'>

# %%
#multivariate analysis
sns.pairplot(df)

# %%
#multivariate analysis
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#task-4:Perform descriptive statistics on the dataset
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
#task-5:Check for Missing values and deal with them.
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
#so, here we need to fill in the null-values
#for numerical columns:
df['culmen_length_mm'].fillna(df['culmen_length_mm'].median(),inplace =True)
df['culmen_depth_mm'].fillna(df['culmen_depth_mm'].median(),inplace =True)
df['flipper_length_mm'].fillna(df['flipper_length_mm'].median(),inplace =True)
df['body_mass_g'].fillna(df['body_mass_g'].median(),inplace =True)

# %%
#for categorical column
df['sex'].fillna('MALE', inplace=True)

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen             39.10             18.7              181.0
# 1    Adelie  Torgersen             39.50             17.4              186.0
# 2    Adelie  Torgersen             40.30             18.0              195.0
# 3    Adelie  Torgersen             44.45             17.3              197.0
# 4    Adelie  Torgersen             36.70             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe             44.45             17.3              197.0
# 340  Gentoo     Biscoe             46.80             14.3              215.0
# 341  Gentoo     Biscoe             50.40             15.7              222.0
# 342  Gentoo     Biscoe             45.20             14.8              212.0
# 343  Gentoo     Biscoe             49.90             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
#TASK-6:Find the outliers and replace them outliers
sns.boxplot(df.culmen_length_mm)
# Out:
# C:\Users\putikam yashwanth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='culmen_length_mm'>

# %%
q1 = df.culmen_length_mm.quantile(0.25)
q3 = df.culmen_length_mm.quantile(0.75)
print(q1)
print(q3)
# Out:
# 39.275
# 48.5

# %%
IQR=q3-q1
IQR
# Out:
# 9.225000000000001

# %%
upper_limit = q3+1.5*IQR
upper_limit
# Out:
# 62.337500000000006

# %%
lower_limit =q1-1.5*IQR
lower_limit
# Out:
# 25.437499999999996

# %%
(df['culmen_length_mm']>upper_limit)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: culmen_length_mm, Length: 344, dtype: bool

# %%
(df['culmen_length_mm']<lower_limit)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: culmen_length_mm, Length: 344, dtype: bool

# %%
q1 = df.culmen_depth_mm.quantile(0.25)
q3 = df.culmen_depth_mm.quantile(0.75)
print(q1)
print(q3)
# Out:
# 15.6
# 18.7

# %%
IQR=q3-q1
IQR
# Out:
# 3.0999999999999996

# %%
upper_limit = q3+1.5*IQR
upper_limit
# Out:
# 23.349999999999998

# %%
lower_limit =q1-1.5*IQR
lower_limit
# Out:
# 10.95

# %%
(df['culmen_depth_mm']>upper_limit)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: culmen_depth_mm, Length: 344, dtype: bool

# %%
(df['culmen_depth_mm']<lower_limit)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: culmen_depth_mm, Length: 344, dtype: bool

# %%
q1 = df.flipper_length_mm.quantile(0.25)
q3 = df.flipper_length_mm.quantile(0.75)
print(q1)
print(q3)
# Out:
# 190.0
# 213.0

# %%
IQR=q3-q1
IQR
# Out:
# 23.0

# %%
upper_limit = q3+1.5*IQR
upper_limit
# Out:
# 247.5

# %%
lower_limit =q1-1.5*IQR
lower_limit
# Out:
# 155.5

# %%
(df['flipper_length_mm']<lower_limit)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: flipper_length_mm, Length: 344, dtype: bool

# %%
(df['flipper_length_mm']>upper_limit)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: flipper_length_mm, Length: 344, dtype: bool

# %%
q1 = df.body_mass_g.quantile(0.25)
q3 = df.body_mass_g.quantile(0.75)
print(q1)
print(q3)
# Out:
# 3550.0
# 4750.0

# %%
IQR=q3-q1
IQR
# Out:
# 1200.0

# %%
upper_limit = q3+1.5*IQR
upper_limit
# Out:
# 6550.0

# %%
lower_limit =q1-1.5*IQR
lower_limit
# Out:
# 1750.0

# %%
(df['body_mass_g']>upper_limit)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: body_mass_g, Length: 344, dtype: bool

# %%
(df['body_mass_g']<lower_limit)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: body_mass_g, Length: 344, dtype: bool

# %%
#SO, WE HAVE NO OUTLIERS PRESENT IN THIS DATASET

# %%
#TASK-7:Check the correlation of independent variables with the target
df.corr()
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235000           0.655858
# culmen_depth_mm           -0.235000         1.000000          -0.583832
# flipper_length_mm          0.655858        -0.583832           1.000000
# body_mass_g                0.594925        -0.471942           0.871221
#
#                    body_mass_g
# culmen_length_mm      0.594925
# culmen_depth_mm      -0.471942
# flipper_length_mm     0.871221
# body_mass_g           1.000000

# %%
#TASK-8:Check for Categorical columns and perform encoding
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df.sex = le.fit_transform(df.sex)
df.species = le.fit_transform(df.species)
df.island=le.fit_transform(df.island)

# %%
df
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2             39.10             18.7              181.0
# 1          0       2             39.50             17.4              186.0
# 2          0       2             40.30             18.0              195.0
# 3          0       2             44.45             17.3              197.0
# 4          0       2             36.70             19.3              193.0
# ..       ...     ...               ...              ...                ...
# 339        2       0             44.45             17.3              197.0
# 340        2       0             46.80             14.3              215.0
# 341        2       0             50.40             15.7              222.0
# 342        2       0             45.20             14.8              212.0
# 343        2       0             49.90             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# ...

# %%
#TASK-9:Split the data into dependent and independent variables.
#here, the target varibale is species
X =df.drop(columns =['species'],axis =1)
X.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0       2             39.10             18.7              181.0       3750.0
# 1       2             39.50             17.4              186.0       3800.0
# 2       2             40.30             18.0              195.0       3250.0
# 3       2             44.45             17.3              197.0       4050.0
# 4       2             36.70             19.3              193.0       3450.0
#
#    sex
# 0    2
# 1    1
# 2    1
# 3    2
# 4    1

# %%
y = df['species']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 339    2
# 340    2
# 341    2
# 342    2
# 343    2
# Name: species, Length: 344, dtype: int64

# %%
#TASK-10:Scaling the data
from sklearn.preprocessing import MinMaxScaler
scale =MinMaxScaler()

# %%
X_scaled= pd.DataFrame(scale.fit_transform(X),columns =X.columns)
X_scaled.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0     1.0          0.254545         0.666667           0.152542     0.291667
# 1     1.0          0.269091         0.511905           0.237288     0.305556
# 2     1.0          0.298182         0.583333           0.389831     0.152778
# 3     1.0          0.449091         0.500000           0.423729     0.375000
# 4     1.0          0.167273         0.738095           0.355932     0.208333
#
#    sex
# 0  1.0
# 1  0.5
# 2  0.5
# 3  1.0
# 4  0.5

# %%
#TASK-11:Split the data into training and testing
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3,random_state=10)

# %%
#TASK-12:check the training and testing data shape
X_train.shape
# Out:
# (240, 6)

# %%
X_train.head()
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 258     0.0          0.432727         0.059524           0.610169
# 332     0.0          0.414545         0.250000           0.694915
# 121     1.0          0.203636         0.797619           0.440678
# 61      0.0          0.334545         0.952381           0.389831
# 70      1.0          0.050909         0.702381           0.305085
#
#      body_mass_g  sex
# 258     0.458333  0.5
# 332     0.541667  0.5
# 121     0.222222  1.0
# 61      0.472222  1.0
# 70      0.250000  0.5

# %%
y_train.shape
# Out:
# (240,)

# %%
X_test.shape
# Out:
# (104, 6)
